# %% [markdown]
# # Trial 2 Undergraduate Thesis
# Goal :
# - Create XGBoost and Linear Regresion Model
# - Get insights from the datas
# - Get the best blanket configuration
#
# Name : Husni Naufal Zuhdi (413821)

# %% [markdown]
# ## Regression exercise with XGBoost

# %%
# Basic Numerical Packages
import numpy as np
import pandas as pd
import csv as csv
import os

# Ploting Packages
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from pylab import *

# XGBoost and Machine Learning related Packages
import xgboost as xgb
from xgboost import plot_importance
import sklearn
from sklearn import metrics
from sklearn.model_selection import cross_validate, cross_val_score, KFold, train_test_split, GridSearchCV
from scipy.stats import skew
from collections import OrderedDict

# %%
# Set Cloud Storage Service Account
from google.cloud import storage
client = storage.Client.from_service_account_json(
    'key.json', project='iter-tritium-breeding-xgboost'
)

# %%
# Set variables of result file
enrich_lis = [0.1, 0.3, 0.5, 0.7, 0.9]
mod_ratios = [0, 0.1, 0.3, 0.5, 0.7, 0.9]
neutron_multis = [0, 0.1, 0.3, 0.5, 0.7, 0.9]
bucket = client.bucket("iter-tritium-breeding-xgboost-bucket") # Your bucket name
result_uri = "v2/results/" # Result.json files uri

# Download all result.json file in Cloud Storage Bucket
for enrich_li in enrich_lis:
    for mod_ratio in mod_ratios:
        for neutron_multi in neutron_multis:
            try:
                print("Downloading : " + str(enrich_li) + "-" + str(mod_ratio) + "-" + str(neutron_multi) + "-100-1000.json")
                blob = bucket.blob(result_uri + str(enrich_li) + "-" + str(mod_ratio) + "-" + str(neutron_multi) + "-100-1000.json")
                blob.download_to_filename("result/" + str(enrich_li) + "-" + str(mod_ratio) + "-" + str(neutron_multi) + "-100-1000.json")
            except Exception:
                pass
# Out:
# Downloading : 0.1-0-0-100-1000.json
# Downloading : 0.1-0-0.1-100-1000.json
# Downloading : 0.1-0-0.3-100-1000.json
# Downloading : 0.1-0-0.5-100-1000.json
# Downloading : 0.1-0-0.7-100-1000.json
# Downloading : 0.1-0-0.9-100-1000.json
# Downloading : 0.1-0.1-0-100-1000.json
# Downloading : 0.1-0.1-0.1-100-1000.json
# Downloading : 0.1-0.1-0.3-100-1000.json
# Downloading : 0.1-0.1-0.5-100-1000.json
# Downloading : 0.1-0.1-0.7-100-1000.json
# Downloading : 0.1-0.1-0.9-100-1000.json
# Downloading : 0.1-0.3-0-100-1000.json
# Downloading : 0.1-0.3-0.1-100-1000.json
# Downloading : 0.1-0.3-0.3-100-1000.json
# Downloading : 0.1-0.3-0.5-100-1000.json
# Downloading : 0.1-0.3-0.7-100-1000.json
# Downloading : 0.1-0.3-0.9-100-1000.json
# Downloading : 0.1-0.5-0-100-1000.json
# Downloading : 0.1-0.5-0.1-100-1000.json
# Downloading : 0.1-0.5-0.3-100-1000.json
# Downloading : 0.1-0.5-0.5-100-1000.json
# Downloading : 0.1-0.5-0.7-100-1000.json
# Downloading : 0.1-0.5-0.9-100-1000.json
# Downloading : 0.1-0.7-0-100-1000.json
# Downloading : 0.1-0.7-0.1-100-1000.json
# Downloading : 0.1-0.7-0.3-100-1000.json
# Downloading : 0.1-0.7-0.5-100-1000.json
# Downloading : 0.1-0.7-0.7-100-1000.json
# Downloading : 0.1-0.7-0.9-100-1000.json
# Downloading : 0.1-0.9-0-100-1000.json
# Downloading : 0.1-0.9-0.1-100-1000.json
# Downloading : 0.1-0.9-0.3-100-1000.json
# Downloading : 0.1-0.9-0.5-100-1000.json
# Downloading : 0.1-0.9-0.7-100-1000.json
# Downloading : 0.1-0.9-0.9-100-1000.json
# Downloading : 0.3-0-0-100-1000.json
# Downloading : 0.3-0-0.1-100-1000.json
# Downloading : 0.3-0-0.3-100-1000.json
# Downloading : 0.3-0-0.5-100-1000.json
# Downloading : 0.3-0-0.7-100-1000.json
# Downloading : 0.3-0-0.9-100-1000.json
# Downloading : 0.3-0.1-0-100-1000.json
# Downloading : 0.3-0.1-0.1-100-1000.json
# Downloading : 0.3-0.1-0.3-100-1000.json
# Downloading : 0.3-0.1-0.5-100-1000.json
# Downloading : 0.3-0.1-0.7-100-1000.json
# Downloading : 0.3-0.1-0.9-100-1000.json
# Downloading : 0.3-0.3-0-100-1000.json
# Downloading : 0.3-0.3-0.1-100-1000.json
# Downloading : 0.3-0.3-0.3-100-1000.json
# Downloading : 0.3-0.3-0.5-100-1000.json
# Downloading : 0.3-0.3-0.7-100-1000.json
# Downloading : 0.3-0.3-0.9-100-1000.json
# Downloading : 0.3-0.5-0-100-1000.json
# Downloading : 0.3-0.5-0.1-100-1000.json
# Downloading : 0.3-0.5-0.3-100-1000.json
# Downloading : 0.3-0.5-0.5-100-1000.json
# Downloading : 0.3-0.5-0.7-100-1000.json
# Downloading : 0.3-0.5-0.9-100-1000.json
# Downloading : 0.3-0.7-0-100-1000.json
# Downloading : 0.3-0.7-0.1-100-1000.json
# Downloading : 0.3-0.7-0.3-100-1000.json
# Downloading : 0.3-0.7-0.5-100-1000.json
# Downloading : 0.3-0.7-0.7-100-1000.json
# Downloading : 0.3-0.7-0.9-100-1000.json
# Downloading : 0.3-0.9-0-100-1000.json
# Downloading : 0.3-0.9-0.1-100-1000.json
# Downloading : 0.3-0.9-0.3-100-1000.json
# Downloading : 0.3-0.9-0.5-100-1000.json
# Downloading : 0.3-0.9-0.7-100-1000.json
# Downloading : 0.3-0.9-0.9-100-1000.json
# Downloading : 0.5-0-0-100-1000.json
# Downloading : 0.5-0-0.1-100-1000.json
# Downloading : 0.5-0-0.3-100-1000.json
# Downloading : 0.5-0-0.5-100-1000.json
# Downloading : 0.5-0-0.7-100-1000.json
# Downloading : 0.5-0-0.9-100-1000.json
# Downloading : 0.5-0.1-0-100-1000.json
# Downloading : 0.5-0.1-0.1-100-1000.json
# Downloading : 0.5-0.1-0.3-100-1000.json
# Downloading : 0.5-0.1-0.5-100-1000.json
# Downloading : 0.5-0.1-0.7-100-1000.json
# Downloading : 0.5-0.1-0.9-100-1000.json
# Downloading : 0.5-0.3-0-100-1000.json
# Downloading : 0.5-0.3-0.1-100-1000.json
# Downloading : 0.5-0.3-0.3-100-1000.json
# Downloading : 0.5-0.3-0.5-100-1000.json
# Downloading : 0.5-0.3-0.7-100-1000.json
# Downloading : 0.5-0.3-0.9-100-1000.json
# Downloading : 0.5-0.5-0-100-1000.json
# Downloading : 0.5-0.5-0.1-100-1000.json
# Downloading : 0.5-0.5-0.3-100-1000.json
# Downloading : 0.5-0.5-0.5-100-1000.json
# Downloading : 0.5-0.5-0.7-100-1000.json
# Downloading : 0.5-0.5-0.9-100-1000.json
# Downloading : 0.5-0.7-0-100-1000.json
# Downloading : 0.5-0.7-0.1-100-1000.json
# Downloading : 0.5-0.7-0.3-100-1000.json
# Downloading : 0.5-0.7-0.5-100-1000.json
# Downloading : 0.5-0.7-0.7-100-1000.json
# Downloading : 0.5-0.7-0.9-100-1000.json
# Downloading : 0.5-0.9-0-100-1000.json
# Downloading : 0.5-0.9-0.1-100-1000.json
# Downloading : 0.5-0.9-0.3-100-1000.json
# Downloading : 0.5-0.9-0.5-100-1000.json
# Downloading : 0.5-0.9-0.7-100-1000.json
# Downloading : 0.5-0.9-0.9-100-1000.json
# Downloading : 0.7-0-0-100-1000.json
# Downloading : 0.7-0-0.1-100-1000.json
# Downloading : 0.7-0-0.3-100-1000.json
# Downloading : 0.7-0-0.5-100-1000.json
# Downloading : 0.7-0-0.7-100-1000.json
# Downloading : 0.7-0-0.9-100-1000.json
# Downloading : 0.7-0.1-0-100-1000.json
# Downloading : 0.7-0.1-0.1-100-1000.json
# Downloading : 0.7-0.1-0.3-100-1000.json
# Downloading : 0.7-0.1-0.5-100-1000.json
# Downloading : 0.7-0.1-0.7-100-1000.json
# Downloading : 0.7-0.1-0.9-100-1000.json
# Downloading : 0.7-0.3-0-100-1000.json
# Downloading : 0.7-0.3-0.1-100-1000.json
# Downloading : 0.7-0.3-0.3-100-1000.json
# Downloading : 0.7-0.3-0.5-100-1000.json
# Downloading : 0.7-0.3-0.7-100-1000.json
# Downloading : 0.7-0.3-0.9-100-1000.json
# Downloading : 0.7-0.5-0-100-1000.json
# Downloading : 0.7-0.5-0.1-100-1000.json
# Downloading : 0.7-0.5-0.3-100-1000.json
# Downloading : 0.7-0.5-0.5-100-1000.json
# Downloading : 0.7-0.5-0.7-100-1000.json
# Downloading : 0.7-0.5-0.9-100-1000.json
# Downloading : 0.7-0.7-0-100-1000.json
# Downloading : 0.7-0.7-0.1-100-1000.json
# Downloading : 0.7-0.7-0.3-100-1000.json
# Downloading : 0.7-0.7-0.5-100-1000.json
# Downloading : 0.7-0.7-0.7-100-1000.json
# Downloading : 0.7-0.7-0.9-100-1000.json
# Downloading : 0.7-0.9-0-100-1000.json
# Downloading : 0.7-0.9-0.1-100-1000.json
# Downloading : 0.7-0.9-0.3-100-1000.json
# Downloading : 0.7-0.9-0.5-100-1000.json
# Downloading : 0.7-0.9-0.7-100-1000.json
# Downloading : 0.7-0.9-0.9-100-1000.json
# Downloading : 0.9-0-0-100-1000.json
# Downloading : 0.9-0-0.1-100-1000.json
# Downloading : 0.9-0-0.3-100-1000.json
# Downloading : 0.9-0-0.5-100-1000.json
# Downloading : 0.9-0-0.7-100-1000.json
# Downloading : 0.9-0-0.9-100-1000.json
# Downloading : 0.9-0.1-0-100-1000.json
# Downloading : 0.9-0.1-0.1-100-1000.json
# Downloading : 0.9-0.1-0.3-100-1000.json
# Downloading : 0.9-0.1-0.5-100-1000.json
# Downloading : 0.9-0.1-0.7-100-1000.json
# Downloading : 0.9-0.1-0.9-100-1000.json
# Downloading : 0.9-0.3-0-100-1000.json
# Downloading : 0.9-0.3-0.1-100-1000.json
# Downloading : 0.9-0.3-0.3-100-1000.json
# Downloading : 0.9-0.3-0.5-100-1000.json
# Downloading : 0.9-0.3-0.7-100-1000.json
# Downloading : 0.9-0.3-0.9-100-1000.json
# Downloading : 0.9-0.5-0-100-1000.json
# Downloading : 0.9-0.5-0.1-100-1000.json
# Downloading : 0.9-0.5-0.3-100-1000.json
# Downloading : 0.9-0.5-0.5-100-1000.json
# Downloading : 0.9-0.5-0.7-100-1000.json
# Downloading : 0.9-0.5-0.9-100-1000.json
# Downloading : 0.9-0.7-0-100-1000.json
# Downloading : 0.9-0.7-0.1-100-1000.json
# Downloading : 0.9-0.7-0.3-100-1000.json
# Downloading : 0.9-0.7-0.5-100-1000.json
# Downloading : 0.9-0.7-0.7-100-1000.json
# Downloading : 0.9-0.7-0.9-100-1000.json
# Downloading : 0.9-0.9-0-100-1000.json
# Downloading : 0.9-0.9-0.1-100-1000.json
# Downloading : 0.9-0.9-0.3-100-1000.json
# Downloading : 0.9-0.9-0.5-100-1000.json
# Downloading : 0.9-0.9-0.7-100-1000.json
# Downloading : 0.9-0.9-0.9-100-1000.json

# %%
# Read folder contain simulation results
path = "/home/husninaufalz/iter-tritium-breeding-xgboost/jupyter-notebooks/2-data-analysis/result"
results = os.listdir(path=path)
results.sort()

# %%
# Read data in each folder
data = []
for result in results:
    # Find enrichment feature
    folder_path = path + str(result)
    folder_list = result.split('-')
    folder_list = folder_list[0:3]
    
    # Read tbr and std dev data
    try:
        json_result = pd.read_json(path + "/" + result)
        json_result = json_result["blanket_fluid_mat_(n,Xt)"]["events per source particle"]
        data.append([folder_list[0], folder_list[1], folder_list[2], json_result['result'], json_result['std. dev.']])
    except Exception:
        pass

# Build dataframe from simulation data
df = pd.DataFrame(data, columns=['Li6_enrichment', 'Moderator_ratio','Neutron_multiplier', 'Tbr_OpenMC', 'Stddev'])

# Convert all dataframe type from string into float
df.Li6_enrichment = df.Li6_enrichment.astype(float)
df.Moderator_ratio = df.Moderator_ratio.astype(float)
df.Neutron_multiplier = df.Neutron_multiplier.astype(float)

# %%
# Plot each features vs TBR
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(20, 4))
ax1.scatter(df.Li6_enrichment*100, df.Tbr_OpenMC, c = "blue", marker = "o")
ax1.set_title("Litium-6 enrichment vs TBR")
ax1.set(xlabel='Litium-6 enrichment (%)', ylabel='TBR')
ax2.scatter(df.Moderator_ratio*100, df.Tbr_OpenMC, c = "yellow", marker = "o")
ax2.set_title("Moderator Ratio vs TBR")
ax2.set(xlabel='Moderator Ratio (%)')
ax3.scatter(df.Neutron_multiplier*100, df.Tbr_OpenMC, c = "red", marker = "o")
ax3.set_title("Neutron Multiplier vs TBR")
ax3.set(xlabel='Neutron Multiplier (%)')
# Out:
# [Text(0.5, 0, 'Neutron Multiplier (%)')]

# %%
# Read the dataset
x = df["Li6_enrichment"].tolist()
y = df["Moderator_ratio"].tolist()
z = df["Tbr_OpenMC"].tolist()

colo = df["Neutron_multiplier"].tolist()

# Creating 3d figures
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

# Configuring colorbar
color_map = cm.ScalarMappable(cmap=cm.plasma)
color_map.set_array(colo)

# Creating the heatmap
img = ax.scatter(x, y, z, marker='o', s=50, c=z, cmap=cm.plasma)
heatmap = plt.colorbar(color_map)
heatmap.set_label('Neutron Multiplier', rotation=270, labelpad=20)

# Adding title and labels
ax.set_title("3D Heatmap from Simulation")
ax.set_xlabel('Li6 Enrichment')
ax.set_ylabel('Moderator Ratio')
ax.set_zlabel('Tritium Breeding Ratio')

# Displaying plot
plt.show()

# %%
# See the best blanket design
df.sort_values(by=['Tbr_OpenMC'], ascending=False).head(10)
# Out:
#      Li6_enrichment  Moderator_ratio  Neutron_multiplier  Tbr_OpenMC    Stddev
# 159             0.9              0.5                 0.9    0.958246  0.003402
# 154             0.9              0.3                 0.9    0.953112  0.003717
# 165             0.9              0.7                 0.9    0.952604  0.002963
# 120             0.7              0.3                 0.9    0.941811  0.003359
# 126             0.7              0.5                 0.9    0.934320  0.003482
# 132             0.7              0.7                 0.9    0.924071  0.003399
# 86              0.5              0.3                 0.9    0.919907  0.003664
# 35              0.3              0.0                 0.0    0.919639  0.002549
# 69              0.5              0.0                 0.0    0.917711  0.003232
# 158             0.9              0.5                 0.7    0.916174  0.003201

# %%
# Split dataset into train and test datasets
features_columns = [col for col in df.columns if col not in ['Tbr_OpenMC', 'Stddev']]
X_train, X_test, y_train, y_test = train_test_split(df[features_columns],df['Tbr_OpenMC'],test_size=.3, random_state=42)

# %%
# Load data into DMatrices
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
# First hyperparameters
params = {
    # Parameters that we are going to tune.
    'max_depth':5,
    'min_child_weight': 1,
    'eta':.1,
    'subsample': 1,
    'colsample_bytree': 1,
    'gamma': 0,
    'reg_alpha': 0,
    # Other parameters
    'objective':'reg:squarederror',
    'eval_metric':'mae',
}

# %%
# First Model
model = xgb.train(
    params,
    dtrain,
    num_boost_round=999,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [0]	Test-mae:0.24205
# [1]	Test-mae:0.21869
# [2]	Test-mae:0.19781
# [3]	Test-mae:0.17875
# [4]	Test-mae:0.16170
# [5]	Test-mae:0.14717
# [6]	Test-mae:0.13414
# [7]	Test-mae:0.12218
# [8]	Test-mae:0.11053
# [9]	Test-mae:0.10061
# [10]	Test-mae:0.09196
# [11]	Test-mae:0.08384
# [12]	Test-mae:0.07661
# [13]	Test-mae:0.07057
# [14]	Test-mae:0.06493
# [15]	Test-mae:0.05930
# [16]	Test-mae:0.05449
# [17]	Test-mae:0.04989
# [18]	Test-mae:0.04588
# [19]	Test-mae:0.04214
# [20]	Test-mae:0.03897
# [21]	Test-mae:0.03581
# [22]	Test-mae:0.03327
# [23]	Test-mae:0.03076
# [24]	Test-mae:0.02872
# [25]	Test-mae:0.02673
# [26]	Test-mae:0.02519
# [27]	Test-mae:0.02349
# [28]	Test-mae:0.02213
# [29]	Test-mae:0.02082
# [30]	Test-mae:0.01988
# [31]	Test-mae:0.01866
# [32]	Test-mae:0.01767
# [33]	Test-mae:0.01687
# [34]	Test-mae:0.01600
# [35]	Test-mae:0.01521
# [36]	Test-mae:0.01460
# [37]	Test-mae:0.01400
# [38]	Test-mae:0.01354
# [39]	Test-mae:0.01306
# [40]	Test-mae:0.01265
# [41]	Test-mae:0.01230
# [42]	Test-mae:0.01202
# [43]	Test-mae:0.01171
# [44]	Test-mae:0.01133
# [45]	Test-mae:0.01099
# [46]	Test-mae:0.01071
# [47]	Test-mae:0.01043
# [48]	Test-mae:0.01023
# [49]	Test-mae:0.01009
# [50]	Test-mae:0.00996
# [51]	Test-mae:0.00984
# [52]	Test-mae:0.00973
# [53]	Test-mae:0.00967
# [54]	Test-mae:0.00959
# [55]	Test-mae:0.00953
# [56]	Test-mae:0.00948
# [57]	Test-mae:0.00940
# [58]	Test-mae:0.00933
# [59]	Test-mae:0.00928
# [60]	Test-mae:0.00922
# [61]	Test-mae:0.00918
# [62]	Test-mae:0.00913
# [63]	Test-mae:0.00906
# [64]	Test-mae:0.00902
# [65]	Test-mae:0.00900
# [66]	Test-mae:0.00897
# [67]	Test-mae:0.00895
# [68]	Test-mae:0.00893
# [69]	Test-mae:0.00890
# [70]	Test-mae:0.00887
# [71]	Test-mae:0.00885
# [72]	Test-mae:0.00879
# [73]	Test-mae:0.00879
# [74]	Test-mae:0.00875
# [75]	Test-mae:0.00874
# [76]	Test-mae:0.00872
# [77]	Test-mae:0.00869
# [78]	Test-mae:0.00863
# [79]	Test-mae:0.00862
# [80]	Test-mae:0.00861
# [81]	Test-mae:0.00860
# [82]	Test-mae:0.00860
# [83]	Test-mae:0.00861
# [84]	Test-mae:0.00861
# [85]	Test-mae:0.00861
# [86]	Test-mae:0.00855
# [87]	Test-mae:0.00854
# [88]	Test-mae:0.00854
# [89]	Test-mae:0.00854
# [90]	Test-mae:0.00853
# [91]	Test-mae:0.00851
# [92]	Test-mae:0.00851
# [93]	Test-mae:0.00848
# [94]	Test-mae:0.00849
# [95]	Test-mae:0.00846
# [96]	Test-mae:0.00843
# [97]	Test-mae:0.00837
# [98]	Test-mae:0.00832
# [99]	Test-mae:0.00828
# [100]	Test-mae:0.00823
# [101]	Test-mae:0.00823
# [102]	Test-mae:0.00823
# [103]	Test-mae:0.00823
# [104]	Test-mae:0.00823
# [105]	Test-mae:0.00823
# [106]	Test-mae:0.00823
# [107]	Test-mae:0.00823
# [108]	Test-mae:0.00823
# [109]	Test-mae:0.00823
# [110]	Test-mae:0.00823

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# Best MAE: 0.01 with 102 rounds

# %%
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=999,
    seed=42,
    nfold=5,
    metrics={'mae'},
    early_stopping_rounds=10
)
cv_results
# Out:
#      train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0          0.250889       0.001674       0.251066      0.007543
# 1          0.226745       0.001512       0.227058      0.007798
# 2          0.205053       0.001423       0.205642      0.007777
# 3          0.185343       0.001276       0.185919      0.007908
# 4          0.167614       0.001145       0.168119      0.007939
# ..              ...            ...            ...           ...
# 103        0.001909       0.000261       0.009788      0.001565
# 104        0.001898       0.000257       0.009790      0.001563
# 105        0.001890       0.000255       0.009788      0.001565
# 106        0.001882       0.000254       0.009787      0.001567
# 107        0.001875       0.000254       0.009784      0.001569
#
# [108 rows x 4 columns]

# %%
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(1,11)
    for min_child_weight in range(1,11)
]

# Define initial best params and MAE
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=999,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with max_depth=1, min_child_weight=1
# 	MAE 0.0203266 for 873 rounds
# CV with max_depth=1, min_child_weight=2
# 	MAE 0.0203266 for 873 rounds
# CV with max_depth=1, min_child_weight=3
# 	MAE 0.0257978 for 835 rounds
# CV with max_depth=1, min_child_weight=4
# 	MAE 0.0288634 for 709 rounds
# CV with max_depth=1, min_child_weight=5
# 	MAE 0.0288634 for 709 rounds
# CV with max_depth=1, min_child_weight=6
# 	MAE 0.0288634 for 709 rounds
# CV with max_depth=1, min_child_weight=7
# 	MAE 0.0288634 for 709 rounds
# CV with max_depth=1, min_child_weight=8
# 	MAE 0.0288634 for 709 rounds
# CV with max_depth=1, min_child_weight=9
# 	MAE 0.030681000000000003 for 412 rounds
# CV with max_depth=1, min_child_weight=10
# 	MAE 0.035576199999999995 for 369 rounds
# CV with max_depth=2, min_child_weight=1
# 	MAE 0.0095018 for 279 rounds
# CV with max_depth=2, min_child_weight=2
# 	MAE 0.009977000000000001 for 296 rounds
# CV with max_depth=2, min_child_weight=3
# 	MAE 0.0169226 for 183 rounds
# CV with max_depth=2, min_child_weight=4
# 	MAE 0.017286600000000003 for 289 rounds
# CV with max_depth=2, min_child_weight=5
# 	MAE 0.018354799999999998 for 228 rounds
# CV with max_depth=2, min_child_weight=6
# 	MAE 0.0175744 for 362 rounds
# CV with max_depth=2, min_child_weight=7
# 	MAE 0.0176896 for 400 rounds
# CV with max_depth=2, min_child_weight=8
# 	MAE 0.0183634 for 280 rounds
# CV with max_depth=2, min_child_weight=9
# 	MAE 0.0215066 for 217 rounds
# CV with max_depth=2, min_child_weight=10
# 	MAE 0.025938 for 341 rounds
# CV with max_depth=3, min_child_weight=1
# 	MAE 0.008805799999999999 for 195 rounds
# CV with max_depth=3, min_child_weight=2
# 	MAE 0.008546 for 197 rounds
# CV with max_depth=3, min_child_weight=3
# 	MAE 0.0166614 for 128 rounds
# CV with max_depth=3, min_child_weight=4
# 	MAE 0.0169016 for 113 rounds
# CV with max_depth=3, min_child_weight=5
# 	MAE 0.017715 for 118 rounds
# CV with max_depth=3, min_child_weight=6
# 	MAE 0.017448200000000004 for 127 rounds
# CV with max_depth=3, min_child_weight=7
# 	MAE 0.0179234 for 157 rounds
# CV with max_depth=3, min_child_weight=8
# 	MAE 0.017027399999999998 for 164 rounds
# CV with max_depth=3, min_child_weight=9
# 	MAE 0.019677800000000002 for 154 rounds
# CV with max_depth=3, min_child_weight=10
# 	MAE 0.0250514 for 117 rounds
# CV with max_depth=4, min_child_weight=1
# 	MAE 0.0091318 for 119 rounds
# CV with max_depth=4, min_child_weight=2
# 	MAE 0.008135400000000001 for 154 rounds
# CV with max_depth=4, min_child_weight=3
# 	MAE 0.0165042 for 96 rounds
# CV with max_depth=4, min_child_weight=4
# 	MAE 0.0167074 for 99 rounds
# CV with max_depth=4, min_child_weight=5
# 	MAE 0.017647200000000002 for 222 rounds
# CV with max_depth=4, min_child_weight=6
# 	MAE 0.016897600000000002 for 130 rounds
# CV with max_depth=4, min_child_weight=7
# 	MAE 0.017622 for 128 rounds
# CV with max_depth=4, min_child_weight=8
# 	MAE 0.018235599999999998 for 101 rounds
# CV with max_depth=4, min_child_weight=9
# 	MAE 0.0191998 for 139 rounds
# CV with max_depth=4, min_child_weight=10
# 	MAE 0.023836600000000003 for 151 rounds
# CV with max_depth=5, min_child_weight=1
# 	MAE 0.0097842 for 107 rounds
# CV with max_depth=5, min_child_weight=2
# 	MAE 0.0083582 for 116 rounds
# CV with max_depth=5, min_child_weight=3
# 	MAE 0.016377799999999998 for 94 rounds
# CV with max_depth=5, min_child_weight=4
# 	MAE 0.0158286 for 108 rounds
# CV with max_depth=5, min_child_weight=5
# 	MAE 0.0167738 for 205 rounds
# CV with max_depth=5, min_child_weight=6
# 	MAE 0.0173688 for 123 rounds
# CV with max_depth=5, min_child_weight=7
# 	MAE 0.0169906 for 139 rounds
# CV with max_depth=5, min_child_weight=8
# 	MAE 0.0176314 for 110 rounds
# CV with max_depth=5, min_child_weight=9
# 	MAE 0.019200599999999998 for 108 rounds
# CV with max_depth=5, min_child_weight=10
# 	MAE 0.024078 for 146 rounds
# CV with max_depth=6, min_child_weight=1
# 	MAE 0.0098382 for 119 rounds
# CV with max_depth=6, min_child_weight=2
# 	MAE 0.0094828 for 116 rounds
# CV with max_depth=6, min_child_weight=3
# 	MAE 0.016480599999999998 for 95 rounds
# CV with max_depth=6, min_child_weight=4
# 	MAE 0.015729399999999998 for 100 rounds
# CV with max_depth=6, min_child_weight=5
# 	MAE 0.0167116 for 241 rounds
# CV with max_depth=6, min_child_weight=6
# 	MAE 0.016638 for 172 rounds
# CV with max_depth=6, min_child_weight=7
# 	MAE 0.0170944 for 150 rounds
# CV with max_depth=6, min_child_weight=8
# 	MAE 0.0179772 for 122 rounds
# CV with max_depth=6, min_child_weight=9
# 	MAE 0.0192534 for 98 rounds
# CV with max_depth=6, min_child_weight=10
# 	MAE 0.0240294 for 140 rounds
# CV with max_depth=7, min_child_weight=1
# 	MAE 0.010454599999999998 for 117 rounds
# CV with max_depth=7, min_child_weight=2
# 	MAE 0.009913400000000001 for 117 rounds
# CV with max_depth=7, min_child_weight=3
# 	MAE 0.0164476 for 75 rounds
# CV with max_depth=7, min_child_weight=4
# 	MAE 0.015836399999999997 for 100 rounds
# CV with max_depth=7, min_child_weight=5
# 	MAE 0.017497199999999997 for 109 rounds
# CV with max_depth=7, min_child_weight=6
# 	MAE 0.0171282 for 96 rounds
# CV with max_depth=7, min_child_weight=7
# 	MAE 0.0173238 for 120 rounds
# CV with max_depth=7, min_child_weight=8
# 	MAE 0.017912400000000002 for 78 rounds
# CV with max_depth=7, min_child_weight=9
# 	MAE 0.0194334 for 115 rounds
# CV with max_depth=7, min_child_weight=10
# 	MAE 0.024042 for 140 rounds
# CV with max_depth=8, min_child_weight=1
# 	MAE 0.0104336 for 124 rounds
# CV with max_depth=8, min_child_weight=2
# 	MAE 0.0098686 for 116 rounds
# CV with max_depth=8, min_child_weight=3
# 	MAE 0.0162872 for 83 rounds
# CV with max_depth=8, min_child_weight=4
# 	MAE 0.0158926 for 97 rounds
# CV with max_depth=8, min_child_weight=5
# 	MAE 0.0168586 for 219 rounds
# CV with max_depth=8, min_child_weight=6
# 	MAE 0.016941 for 128 rounds
# CV with max_depth=8, min_child_weight=7
# 	MAE 0.0172882 for 120 rounds
# CV with max_depth=8, min_child_weight=8
# 	MAE 0.017912400000000002 for 78 rounds
# CV with max_depth=8, min_child_weight=9
# 	MAE 0.0194334 for 115 rounds
# CV with max_depth=8, min_child_weight=10
# 	MAE 0.024042 for 140 rounds
# CV with max_depth=9, min_child_weight=1
# 	MAE 0.010480799999999998 for 126 rounds
# CV with max_depth=9, min_child_weight=2
# 	MAE 0.0099444 for 121 rounds
# CV with max_depth=9, min_child_weight=3
# 	MAE 0.0162196 for 88 rounds
# CV with max_depth=9, min_child_weight=4
# 	MAE 0.0157986 for 77 rounds
# CV with max_depth=9, min_child_weight=5
# 	MAE 0.017623399999999997 for 102 rounds
# CV with max_depth=9, min_child_weight=6
# 	MAE 0.016554600000000003 for 236 rounds
# CV with max_depth=9, min_child_weight=7
# 	MAE 0.0172882 for 120 rounds
# CV with max_depth=9, min_child_weight=8
# 	MAE 0.017912400000000002 for 78 rounds
# CV with max_depth=9, min_child_weight=9
# 	MAE 0.0194334 for 115 rounds
# CV with max_depth=9, min_child_weight=10
# 	MAE 0.024042 for 140 rounds
# CV with max_depth=10, min_child_weight=1
# 	MAE 0.0104358 for 120 rounds
# CV with max_depth=10, min_child_weight=2
# 	MAE 0.009917399999999998 for 124 rounds
# CV with max_depth=10, min_child_weight=3
# 	MAE 0.016217199999999998 for 90 rounds
# CV with max_depth=10, min_child_weight=4
# 	MAE 0.015839199999999998 for 73 rounds
# CV with max_depth=10, min_child_weight=5
# 	MAE 0.017625 for 102 rounds
# CV with max_depth=10, min_child_weight=6
# 	MAE 0.016554600000000003 for 236 rounds
# CV with max_depth=10, min_child_weight=7
# 	MAE 0.0172882 for 120 rounds
# CV with max_depth=10, min_child_weight=8
# 	MAE 0.017912400000000002 for 78 rounds
# CV with max_depth=10, min_child_weight=9
# 	MAE 0.0194334 for 115 rounds
# CV with max_depth=10, min_child_weight=10
# 	MAE 0.024042 for 140 rounds
# Best params: 4, 2, MAE: 0.008135400000000001

# %%
# Update first and second parameters
params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

# %%
gridsearch_params = [
    (subsample, colsample, gamma)
    for subsample in [i/10. for i in range(6,11)]
    for colsample in [i/10. for i in range(6,11)]
    for gamma in [i/10. for i in range(0,6)]
]

min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample, gamma in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}, gamma={}".format(
        subsample,
        colsample,
        gamma))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    params['gamma'] = gamma
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=999,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample,gamma)
print("Best params: {}, {}, {}, MAE: {}".format(best_params[0], best_params[1], best_params[2], min_mae))
# Out:
# CV with subsample=1.0, colsample=1.0, gamma=0.5
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=1.0, gamma=0.4
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=1.0, gamma=0.3
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=1.0, gamma=0.2
# 	MAE 0.0677678 for 37 rounds
# CV with subsample=1.0, colsample=1.0, gamma=0.1
# 	MAE 0.0559302 for 37 rounds
# CV with subsample=1.0, colsample=1.0, gamma=0.0
# 	MAE 0.008135400000000001 for 154 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.5
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.4
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.3
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.2
# 	MAE 0.067145 for 39 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.1
# 	MAE 0.0558264 for 39 rounds
# CV with subsample=1.0, colsample=0.9, gamma=0.0
# 	MAE 0.0105018 for 231 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.5
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.4
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.3
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.2
# 	MAE 0.067145 for 39 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.1
# 	MAE 0.0558264 for 39 rounds
# CV with subsample=1.0, colsample=0.8, gamma=0.0
# 	MAE 0.0105018 for 231 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.5
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.4
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.3
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.2
# 	MAE 0.067145 for 39 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.1
# 	MAE 0.0558264 for 39 rounds
# CV with subsample=1.0, colsample=0.7, gamma=0.0
# 	MAE 0.0105018 for 231 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.5
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.4
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.3
# 	MAE 0.0680628 for 36 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.2
# 	MAE 0.067776 for 37 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.1
# 	MAE 0.059955 for 33 rounds
# CV with subsample=1.0, colsample=0.6, gamma=0.0
# 	MAE 0.020312600000000004 for 375 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.5
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.4
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.3
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.2
# 	MAE 0.06727059999999999 for 41 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.1
# 	MAE 0.053878800000000004 for 47 rounds
# CV with subsample=0.9, colsample=1.0, gamma=0.0
# 	MAE 0.0068336000000000004 for 312 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.5
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.4
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.3
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.2
# 	MAE 0.06727059999999999 for 41 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.1
# 	MAE 0.055037 for 41 rounds
# CV with subsample=0.9, colsample=0.9, gamma=0.0
# 	MAE 0.0104292 for 191 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.5
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.4
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.3
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.2
# 	MAE 0.06727059999999999 for 41 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.1
# 	MAE 0.055037 for 41 rounds
# CV with subsample=0.9, colsample=0.8, gamma=0.0
# 	MAE 0.0104292 for 191 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.5
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.4
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.3
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.2
# 	MAE 0.06727059999999999 for 41 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.1
# 	MAE 0.055037 for 41 rounds
# CV with subsample=0.9, colsample=0.7, gamma=0.0
# 	MAE 0.0104292 for 191 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.5
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.4
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.3
# 	MAE 0.0680132 for 39 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.2
# 	MAE 0.0671538 for 41 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.1
# 	MAE 0.057434200000000005 for 45 rounds
# CV with subsample=0.9, colsample=0.6, gamma=0.0
# 	MAE 0.0204328 for 228 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.5
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.4
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.3
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.2
# 	MAE 0.067093 for 37 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.1
# 	MAE 0.05536340000000001 for 37 rounds
# CV with subsample=0.8, colsample=1.0, gamma=0.0
# 	MAE 0.0066914 for 241 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.5
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.4
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.3
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.2
# 	MAE 0.06714 for 37 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.1
# 	MAE 0.0559596 for 37 rounds
# CV with subsample=0.8, colsample=0.9, gamma=0.0
# 	MAE 0.0101732 for 158 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.5
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.4
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.3
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.2
# 	MAE 0.06714 for 37 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.1
# 	MAE 0.0559596 for 37 rounds
# CV with subsample=0.8, colsample=0.8, gamma=0.0
# 	MAE 0.0101732 for 158 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.5
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.4
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.3
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.2
# 	MAE 0.06714 for 37 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.1
# 	MAE 0.0559596 for 37 rounds
# CV with subsample=0.8, colsample=0.7, gamma=0.0
# 	MAE 0.0101732 for 158 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.5
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.4
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.3
# 	MAE 0.0680436 for 37 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.2
# 	MAE 0.0671504 for 37 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.1
# 	MAE 0.0586996 for 35 rounds
# CV with subsample=0.8, colsample=0.6, gamma=0.0
# 	MAE 0.0209992 for 176 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.5
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.4
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.3
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.2
# 	MAE 0.0673266 for 43 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.1
# 	MAE 0.055167999999999995 for 58 rounds
# CV with subsample=0.7, colsample=1.0, gamma=0.0
# 	MAE 0.006834999999999999 for 182 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.5
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.4
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.3
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.2
# 	MAE 0.06737459999999999 for 40 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.1
# 	MAE 0.05612999999999999 for 43 rounds
# CV with subsample=0.7, colsample=0.9, gamma=0.0
# 	MAE 0.0099606 for 177 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.5
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.4
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.3
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.2
# 	MAE 0.06737459999999999 for 40 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.1
# 	MAE 0.05612999999999999 for 43 rounds
# CV with subsample=0.7, colsample=0.8, gamma=0.0
# 	MAE 0.0099606 for 177 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.5
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.4
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.3
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.2
# 	MAE 0.06737459999999999 for 40 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.1
# 	MAE 0.05612999999999999 for 43 rounds
# CV with subsample=0.7, colsample=0.7, gamma=0.0
# 	MAE 0.0099606 for 177 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.5
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.4
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.3
# 	MAE 0.06806300000000001 for 46 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.2
# 	MAE 0.0677002 for 46 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.1
# 	MAE 0.059515799999999994 for 45 rounds
# CV with subsample=0.7, colsample=0.6, gamma=0.0
# 	MAE 0.021167 for 173 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.5
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.4
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.3
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.2
# 	MAE 0.067263 for 46 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.1
# 	MAE 0.0563462 for 58 rounds
# CV with subsample=0.6, colsample=1.0, gamma=0.0
# 	MAE 0.0072812 for 352 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.5
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.4
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.3
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.2
# 	MAE 0.0673186 for 46 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.1
# 	MAE 0.0571346 for 62 rounds
# CV with subsample=0.6, colsample=0.9, gamma=0.0
# 	MAE 0.0104396 for 181 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.5
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.4
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.3
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.2
# 	MAE 0.0673186 for 46 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.1
# 	MAE 0.0571346 for 62 rounds
# CV with subsample=0.6, colsample=0.8, gamma=0.0
# 	MAE 0.0104396 for 181 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.5
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.4
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.3
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.2
# 	MAE 0.0673186 for 46 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.1
# 	MAE 0.0571346 for 62 rounds
# CV with subsample=0.6, colsample=0.7, gamma=0.0
# 	MAE 0.0104396 for 181 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.5
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.4
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.3
# 	MAE 0.06804940000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.2
# 	MAE 0.06768300000000001 for 46 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.1
# 	MAE 0.057479800000000005 for 135 rounds
# CV with subsample=0.6, colsample=0.6, gamma=0.0
# 	MAE 0.0211646 for 173 rounds
# Best params: 0.8, 1.0, 0.0, MAE: 0.0066914

# %%
# Update third and fourth parameters
params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]
params['gamma'] = best_params[2]

# %%
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [0, 1e-5, 1e-2, 0,1, 1, 100]

# Define initial best params and MAE
min_mae = float("Inf")
best_params = None
for reg_alpha in gridsearch_params:
    print("CV with reg_alpha={}".format(reg_alpha))
    # Update our parameters
    params['reg_alpha'] = reg_alpha
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=999,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = reg_alpha
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# CV with reg_alpha=0
# 	MAE 0.0066914 for 241 rounds
# CV with reg_alpha=1e-05
# 	MAE 0.006713800000000001 for 245 rounds
# CV with reg_alpha=0.01
# 	MAE 0.007867 for 289 rounds
# CV with reg_alpha=0
# 	MAE 0.0066914 for 241 rounds
# CV with reg_alpha=1
# 	MAE 0.035025600000000004 for 215 rounds
# CV with reg_alpha=1
# 	MAE 0.035025600000000004 for 215 rounds
# CV with reg_alpha=100
# 	MAE 0.27767200000000003 for 0 rounds
# Best params: 0, MAE: 0.0066914

# %%
# Update reg_alpha parameters
params['reg_alpha'] = best_params

# %%
# %time
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [0.01, 0.05, 0.07, 0.1, 0.3, 0.5]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    # %time cv_results = xgb.cv(params,dtrain,num_boost_round=999,seed=42,nfold=5,metrics=['mae'],early_stopping_rounds=10)
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.39 µs
# CV with eta=0.01
# CPU times: user 7.11 s, sys: 91.8 ms, total: 7.2 s
# Wall time: 1.81 s
# 	MAE 0.008331 for 998 rounds
#
# CV with eta=0.05
# CPU times: user 3.49 s, sys: 27.9 ms, total: 3.52 s
# Wall time: 883 ms
# 	MAE 0.006762799999999999 for 472 rounds
#
# CV with eta=0.07
# CPU times: user 2.87 s, sys: 17.7 ms, total: 2.89 s
# Wall time: 726 ms
# 	MAE 0.007197400000000001 for 393 rounds
#
# CV with eta=0.1
# CPU times: user 1.82 s, sys: 3.93 ms, total: 1.82 s
# Wall time: 458 ms
# 	MAE 0.0066914 for 241 rounds
#
# CV with eta=0.3
# CPU times: user 1.1 s, sys: 12 ms, total: 1.11 s
# Wall time: 280 ms
# 	MAE 0.008813999999999999 for 146 rounds
#
# CV with eta=0.5
# CPU times: user 754 ms, sys: 11.9 ms, total: 766 ms
# Wall time: 193 ms
# 	MAE 0.0101608 for 97 rounds
#
# Best params: 0.1, MAE: 0.0066914

# %%
# Update fifth parameters
params['eta'] = best_params

# %%
new_model = xgb.train(
    params,
    dtrain,
    num_boost_round=999,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} in {} rounds".format(model.best_score, model.best_iteration+1))
# Out:
# [0]	Test-mae:0.24196
# [1]	Test-mae:0.21902
# [2]	Test-mae:0.19758
# [3]	Test-mae:0.17796
# [4]	Test-mae:0.16175
# [5]	Test-mae:0.14625
# [6]	Test-mae:0.13252
# [7]	Test-mae:0.12029
# [8]	Test-mae:0.11031
# [9]	Test-mae:0.10061
# [10]	Test-mae:0.09177
# [11]	Test-mae:0.08410
# [12]	Test-mae:0.07654
# [13]	Test-mae:0.06960
# [14]	Test-mae:0.06401
# [15]	Test-mae:0.05847
# [16]	Test-mae:0.05344
# [17]	Test-mae:0.04937
# [18]	Test-mae:0.04519
# [19]	Test-mae:0.04186
# [20]	Test-mae:0.03891
# [21]	Test-mae:0.03586
# [22]	Test-mae:0.03308
# [23]	Test-mae:0.03062
# [24]	Test-mae:0.02845
# [25]	Test-mae:0.02652
# [26]	Test-mae:0.02472
# [27]	Test-mae:0.02324
# [28]	Test-mae:0.02162
# [29]	Test-mae:0.02066
# [30]	Test-mae:0.01991
# [31]	Test-mae:0.01921
# [32]	Test-mae:0.01824
# [33]	Test-mae:0.01758
# [34]	Test-mae:0.01692
# [35]	Test-mae:0.01630
# [36]	Test-mae:0.01560
# [37]	Test-mae:0.01491
# [38]	Test-mae:0.01435
# [39]	Test-mae:0.01376
# [40]	Test-mae:0.01333
# [41]	Test-mae:0.01280
# [42]	Test-mae:0.01235
# [43]	Test-mae:0.01192
# [44]	Test-mae:0.01161
# [45]	Test-mae:0.01115
# [46]	Test-mae:0.01089
# [47]	Test-mae:0.01078
# [48]	Test-mae:0.01057
# [49]	Test-mae:0.01033
# [50]	Test-mae:0.01023
# [51]	Test-mae:0.01007
# [52]	Test-mae:0.00996
# [53]	Test-mae:0.00983
# [54]	Test-mae:0.00967
# [55]	Test-mae:0.00945
# [56]	Test-mae:0.00928
# [57]	Test-mae:0.00917
# [58]	Test-mae:0.00909
# [59]	Test-mae:0.00896
# [60]	Test-mae:0.00895
# [61]	Test-mae:0.00894
# [62]	Test-mae:0.00880
# [63]	Test-mae:0.00877
# [64]	Test-mae:0.00864
# [65]	Test-mae:0.00858
# [66]	Test-mae:0.00849
# [67]	Test-mae:0.00841
# [68]	Test-mae:0.00837
# [69]	Test-mae:0.00831
# [70]	Test-mae:0.00823
# [71]	Test-mae:0.00818
# [72]	Test-mae:0.00805
# [73]	Test-mae:0.00794
# [74]	Test-mae:0.00789
# [75]	Test-mae:0.00783
# [76]	Test-mae:0.00776
# [77]	Test-mae:0.00769
# [78]	Test-mae:0.00765
# [79]	Test-mae:0.00767
# [80]	Test-mae:0.00767
# [81]	Test-mae:0.00763
# [82]	Test-mae:0.00760
# [83]	Test-mae:0.00754
# [84]	Test-mae:0.00750
# [85]	Test-mae:0.00751
# [86]	Test-mae:0.00748
# [87]	Test-mae:0.00746
# [88]	Test-mae:0.00745
# [89]	Test-mae:0.00736
# [90]	Test-mae:0.00731
# [91]	Test-mae:0.00728
# [92]	Test-mae:0.00725
# [93]	Test-mae:0.00723
# [94]	Test-mae:0.00723
# [95]	Test-mae:0.00717
# [96]	Test-mae:0.00714
# [97]	Test-mae:0.00713
# [98]	Test-mae:0.00708
# [99]	Test-mae:0.00707
# [100]	Test-mae:0.00704
# [101]	Test-mae:0.00703
# [102]	Test-mae:0.00702
# [103]	Test-mae:0.00699
# [104]	Test-mae:0.00698
# [105]	Test-mae:0.00697
# [106]	Test-mae:0.00696
# [107]	Test-mae:0.00691
# [108]	Test-mae:0.00690
# [109]	Test-mae:0.00689
# [110]	Test-mae:0.00685
# [111]	Test-mae:0.00687
# [112]	Test-mae:0.00684
# [113]	Test-mae:0.00680
# [114]	Test-mae:0.00681
# [115]	Test-mae:0.00680
# [116]	Test-mae:0.00681
# [117]	Test-mae:0.00680
# [118]	Test-mae:0.00681
# [119]	Test-mae:0.00681
# [120]	Test-mae:0.00680
# [121]	Test-mae:0.00678
# [122]	Test-mae:0.00675
# [123]	Test-mae:0.00676
# [124]	Test-mae:0.00677
# [125]	Test-mae:0.00678
# [126]	Test-mae:0.00678
# [127]	Test-mae:0.00678
# [128]	Test-mae:0.00675
# [129]	Test-mae:0.00675
# [130]	Test-mae:0.00674
# [131]	Test-mae:0.00673
# [132]	Test-mae:0.00672
# [133]	Test-mae:0.00670
# [134]	Test-mae:0.00669
# [135]	Test-mae:0.00669
# [136]	Test-mae:0.00669
# [137]	Test-mae:0.00671
# [138]	Test-mae:0.00669
# [139]	Test-mae:0.00671
# [140]	Test-mae:0.00669
# [141]	Test-mae:0.00668
# [142]	Test-mae:0.00667
# [143]	Test-mae:0.00668
# [144]	Test-mae:0.00668
# [145]	Test-mae:0.00667
# [146]	Test-mae:0.00669
# [147]	Test-mae:0.00668
# [148]	Test-mae:0.00668
# [149]	Test-mae:0.00664
# [150]	Test-mae:0.00662
# [151]	Test-mae:0.00661
# [152]	Test-mae:0.00661
# [153]	Test-mae:0.00660
# [154]	Test-mae:0.00658
# [155]	Test-mae:0.00655
# [156]	Test-mae:0.00655
# [157]	Test-mae:0.00655
# [158]	Test-mae:0.00655
# [159]	Test-mae:0.00655
# [160]	Test-mae:0.00656
# [161]	Test-mae:0.00657
# [162]	Test-mae:0.00656
# [163]	Test-mae:0.00656
# [164]	Test-mae:0.00654
# [165]	Test-mae:0.00651
# [166]	Test-mae:0.00649
# [167]	Test-mae:0.00648
# [168]	Test-mae:0.00649
# [169]	Test-mae:0.00650
# [170]	Test-mae:0.00650
# [171]	Test-mae:0.00650
# [172]	Test-mae:0.00649
# [173]	Test-mae:0.00649
# [174]	Test-mae:0.00650
# [175]	Test-mae:0.00649
# [176]	Test-mae:0.00649
# [177]	Test-mae:0.00647
# [178]	Test-mae:0.00647
# [179]	Test-mae:0.00647
# [180]	Test-mae:0.00644
# [181]	Test-mae:0.00643
# [182]	Test-mae:0.00642
# [183]	Test-mae:0.00640
# [184]	Test-mae:0.00638
# [185]	Test-mae:0.00638
# [186]	Test-mae:0.00637
# [187]	Test-mae:0.00637
# [188]	Test-mae:0.00636
# [189]	Test-mae:0.00635
# [190]	Test-mae:0.00636
# [191]	Test-mae:0.00636
# [192]	Test-mae:0.00635
# [193]	Test-mae:0.00636
# [194]	Test-mae:0.00634
# [195]	Test-mae:0.00634
# [196]	Test-mae:0.00636
# [197]	Test-mae:0.00636
# [198]	Test-mae:0.00635
# [199]	Test-mae:0.00633
# [200]	Test-mae:0.00633
# [201]	Test-mae:0.00633
# [202]	Test-mae:0.00634
# [203]	Test-mae:0.00634
# [204]	Test-mae:0.00635
# [205]	Test-mae:0.00634
# [206]	Test-mae:0.00634
# [207]	Test-mae:0.00632
# [208]	Test-mae:0.00632
# [209]	Test-mae:0.00631
# [210]	Test-mae:0.00630
# [211]	Test-mae:0.00629
# [212]	Test-mae:0.00628
# [213]	Test-mae:0.00628
# [214]	Test-mae:0.00628
# [215]	Test-mae:0.00628
# [216]	Test-mae:0.00627
# [217]	Test-mae:0.00627
# [218]	Test-mae:0.00627
# [219]	Test-mae:0.00627
# [220]	Test-mae:0.00628
# [221]	Test-mae:0.00627
# [222]	Test-mae:0.00626
# [223]	Test-mae:0.00627
# [224]	Test-mae:0.00626
# [225]	Test-mae:0.00626
# [226]	Test-mae:0.00626
# [227]	Test-mae:0.00627
# [228]	Test-mae:0.00626
# [229]	Test-mae:0.00626
# [230]	Test-mae:0.00626
# [231]	Test-mae:0.00627
# [232]	Test-mae:0.00627
# [233]	Test-mae:0.00628
# Best MAE: 0.01 in 102 rounds

# %%
# Build a validation dataframe
data_val = []
enrich = [0.05*x for x in range(1,21)]
nm = [0.05*x for x in range(1,21)]
mod = [0.05*x for x in range(1,21)]
for i in enrich:
    for j in mod:
        for k in nm:
            data_val.append([i, j, k, 0, 0])
            
df_val = pd.DataFrame(data_val,
                      columns=['Li6_enrichment',
                               'Moderator_ratio',
                               'Neutron_multiplier',
                               'Tbr_XGBoost',
                               'Tbr_OpenMC'
                              ]
                     )

# %%
# Move TBR_OpenMC in df dataframe into d_val dataframe
for i in enrich:
    for j in mod:
        for k in nm:
            try:
                tbr_row = df.loc[(df["Li6_enrichment"] == i) & (df["Moderator_ratio"] == j) & (df["Neutron_multiplier"] == k)]
                tbr_row = tbr_row['Tbr_OpenMC']
                tbr_row = tbr_row.to_numpy()

                tbr_ml_row = df_val.loc[(df_val["Li6_enrichment"] == i) & (df_val["Moderator_ratio"] == j) & (df_val["Neutron_multiplier"] == k)]
                df_val.iloc[tbr_ml_row.index, 4] = tbr_row[0]
                print("Move TBR_OpenMC in df dataframe into d_val dataframe")
            except Exception:
                pass
# Out:
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe
# Move TBR_OpenMC in df dataframe into d_val dataframe

# %%
# Make predictions with best model for validation data
features_columns = ['Li6_enrichment', 'Moderator_ratio', 'Neutron_multiplier']
dval = xgb.DMatrix(df_val[features_columns])
y_pred = new_model.predict(dval)
df_val['Tbr_XGBoost'] = y_pred

# %%
df_val.sort_values(by=['Tbr_XGBoost'], ascending=False).head(20)
# Out:
#       Li6_enrichment  Moderator_ratio  Neutron_multiplier  Tbr_XGBoost  \
# 6176            0.80             0.45                0.85     0.956562
# 6998            0.90             0.50                0.95     0.956562
# 7816            1.00             0.55                0.85     0.956562
# 7817            1.00             0.55                0.90     0.956562
# 7818            1.00             0.55                0.95     0.956562
# 7819            1.00             0.55                1.00     0.956562
# 7017            0.90             0.55                0.90     0.956562
# 7016            0.90             0.55                0.85     0.956562
# 6179            0.80             0.45                1.00     0.956562
# 7015            0.90             0.55                0.80     0.956562
# 6175            0.80             0.45                0.80     0.956562
# 6999            0.90             0.50                1.00     0.956562
# 6997            0.90             0.50                0.90     0.956562
# 7018            0.90             0.55                0.95     0.956562
# 6996            0.90             0.50                0.85     0.956562
# 6995            0.90             0.50                0.80     0.956562
# 6979            0.90             0.45                1.00     0.956562
# 6619            0.85             0.55                1.00     0.956562
# 6618            0.85             0.55                0.95     0.956562
# 6617            0.85             0.55                0.90     0.956562
#
#       Tbr_OpenMC
# 6176    0.000000
# 6998    0.000000
# 7816    0.000000
# 7817    0.000000
# 7818    0.000000
# 7819    0.000000
# 7017    0.000000
# 7016    0.000000
# 6179    0.000000
# 7015    0.000000
# 6175    0.000000
# 6999    0.000000
# 6997    0.958246
# 7018    0.000000
# 6996    0.000000
# 6995    0.000000
# 6979    0.000000
# 6619    0.000000
# 6618    0.000000
# 6617    0.000000

# %%
# Plot each features vs TBR
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(20, 4))
ax1.scatter(df_val.Li6_enrichment*100, df_val.Tbr_XGBoost, c = "blue", marker = "o")
ax1.scatter(df_val.Li6_enrichment*100, df_val.Tbr_OpenMC, c = "purple", marker = "o")
ax1.set_title("Litium-6 enrichment vs TBR")
ax1.set(xlabel='Litium-6 enrichment (%)', ylabel='TBR')
ax2.scatter(df_val.Moderator_ratio*100, df_val.Tbr_XGBoost, c = "yellow", marker = "o")
ax2.scatter(df_val.Moderator_ratio*100, df_val.Tbr_OpenMC, c = "orange", marker = "o")
ax2.set_title("Moderator Ratio vs TBR")
ax2.set(xlabel='Moderator Ratio (%)')
ax3.scatter(df_val.Neutron_multiplier*100, df_val.Tbr_XGBoost, c = "red", marker = "o")
ax3.scatter(df_val.Neutron_multiplier*100, df_val.Tbr_OpenMC, c = "pink", marker = "o")
ax3.set_title("Neutron Multiplier vs TBR")
ax3.set(xlabel='Neutron Multiplier (%)')
# Out:
# [Text(0.5, 0, 'Neutron Multiplier (%)')]

# %%
# Read the dataset
x = df_val["Li6_enrichment"].tolist()
y = df_val["Moderator_ratio"].tolist()
z = df_val["Tbr_XGBoost"].tolist()

colo = df_val["Neutron_multiplier"].tolist()

# Creating 3d figures
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

# Configuring colorbar
color_map = cm.ScalarMappable(cmap=cm.plasma)
color_map.set_array(colo)

# Creating the heatmap
img = ax.scatter(x, y, z, marker='o', s=50, c=z, cmap=cm.plasma)
heatmap = plt.colorbar(color_map)
heatmap.set_label('Neutron Multiplier', rotation=270, labelpad=20)

# Adding title and labels
ax.set_title("3D Heatmap from Simulation")
ax.set_xlabel('Li6 Enrichment')
ax.set_ylabel('Moderator Ratio')
ax.set_zlabel('Tritium Breeding Ratio')

# Displaying plot
plt.show()

# %%
xgb.plot_importance(model)
xgb.plot_importance(new_model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
